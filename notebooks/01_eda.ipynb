# %% [markdown]
# # 01. Exploratory Data Analysis (EDA)
#
# ## Notebook Overview
# This notebook will explore the raw datasets provided in `data/raw/` for Source 1, Source 2, Source 3, and Ground Truth.
#
# ## TODO
# - [ ] Load raw data files once placed in `data/raw/`.
# - [ ] Discover schemas, column types, and record counts across all sources.
# - [ ] Analyze missing value distributions and duplicate records.
# - [ ] Inspect business name patterns, punctuation, and common entity terms.
# - [ ] Inspect address patterns, formatting variations, and spatial coverage.
# - [ ] Analyze ground truth match distribution (singletons vs multi-matches).
# - [ ] Formulate initial blocking hypotheses based on findings.
# - [ ] Populate `reports/EDA_REPORT.md` with verified insights.
