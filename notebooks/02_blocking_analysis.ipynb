# %% [markdown]
# # 02. Blocking Analysis & Candidate Generation
#
# ## Notebook Overview
# This notebook will test candidate blocking strategies and measure candidate recall against ground truth training pairs.
#
# ## TODO
# - [ ] Evaluate multi-pass blocking keys (n-gram, token prefix, locality).
# - [ ] Measure candidate reduction ratio vs blocking recall.
# - [ ] Analyze missed ground truth pairs (blocking false negatives).
# - [ ] Export candidate pairs to `outputs/candidates/`.
