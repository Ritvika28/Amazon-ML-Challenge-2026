# %% [markdown]
# # 03. Feature Engineering Analysis
#
# ## Notebook Overview
# This notebook will analyze pairwise feature distributions and evaluate feature importance for candidate pair classification.
#
# ## TODO
# - [ ] Compute name and address similarity features for candidate pairs.
# - [ ] Check feature correlations and signal strength between matching vs non-matching pairs.
# - [ ] Select optimal feature subset for classifier training.
