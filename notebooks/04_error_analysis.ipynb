# %% [markdown]
# # 04. Error Analysis & Diagnostics
#
# ## Notebook Overview
# This notebook will diagnose classification errors, analyze false positives and false negatives, and evaluate threshold impacts on Macro F0.5.
#
# ## TODO
# - [ ] Analyze model confidence on false positive matches.
# - [ ] Inspect false negative matches for missed patterns or feature gaps.
# - [ ] Audit singleton vs multi-match decision performance.
# - [ ] Populate `reports/ERROR_ANALYSIS.md` with diagnostic findings.
